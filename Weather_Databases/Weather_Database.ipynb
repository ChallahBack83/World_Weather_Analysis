# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
import random
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
len(coordinates)
# Out:
# 2000

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []


# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 777

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+ weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    #Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    #Log the URL, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    #Add 1 to the record count.
    
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()

           # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]


        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Current Description": city_description
                         })

        # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
    pass

 

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | siavonga
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | karratha
# Processing Record 4 of Set 1 | iranshahr
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | chuy
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | sao joao da barra
# Processing Record 10 of Set 1 | pisco
# Processing Record 11 of Set 1 | mbamba
# Processing Record 12 of Set 1 | severo-kurilsk
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | avarua
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | krasnoselkup
# Processing Record 18 of Set 1 | biak
# Processing Record 19 of Set 1 | kieta
# Processing Record 20 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 1 | buraydah
# Processing Record 22 of Set 1 | poum
# Processing Record 23 of Set 1 | of
# City not found. Skipping...
# Processing Record 24 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 1 | haverfordwest
# Processing Record 26 of Set 1 | kavaratti
# Processing Record 27 of Set 1 | yellowknife
# Processing Record 28 of Set 1 | general pico
# Processing Record 29 of Set 1 | barrow
# Processing Record 30 of Set 1 | bluff
# Processing Record 31 of Set 1 | kanniyakumari
# Processing Record 32 of Set 1 | turukhansk
# Processing Record 33 of Set 1 | sitka
# Processing Record 34 of Set 1 | new norfolk
# Processing Record 35 of Set 1 | kodinsk
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | dingle
# Processing Record 38 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 1 | san patricio
# Processing Record 40 of Set 1 | georgetown
# Processing Record 41 of Set 1 | kapaa
# Processing Record 42 of Set 1 | tiksi
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | rolim de moura
# City not found. Skipping...
# Processing Record 45 of Set 1 | thompson
# Processing Record 46 of Set 1 | alugan
# Processing Record 47 of Set 1 | labuhan
# Processing Record 48 of Set 1 | pirgos
# Processing Record 49 of Set 1 | havre
# Processing Record 50 of Set 1 | leningradskiy
# Processing Record 1 of Set 2 | puerto ayora
# Processing Record 2 of Set 2 | buariki
# City not found. Skipping...
# Processing Record 3 of Set 2 | moose factory
# Processing Record 4 of Set 2 | williston
# Processing Record 5 of Set 2 | punta arenas
# Processing Record 6 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 2 | padang
# Processing Record 8 of Set 2 | merauke
# Processing Record 9 of Set 2 | koutiala
# Processing Record 10 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 11 of Set 2 | coro
# Processing Record 12 of Set 2 | tasiilaq
# Processing Record 13 of Set 2 | longyearbyen
# Processing Record 14 of Set 2 | vardo
# Processing Record 15 of Set 2 | lagoa
# Processing Record 16 of Set 2 | ilulissat
# Processing Record 17 of Set 2 | lebu
# Processing Record 18 of Set 2 | kodiak
# Processing Record 19 of Set 2 | saint-philippe
# Processing Record 20 of Set 2 | zhanatas
# City not found. Skipping...
# Processing Record 21 of Set 2 | jinka
# Processing Record 22 of Set 2 | cape town
# Processing Record 23 of Set 2 | ribeira grande
# Processing Record 24 of Set 2 | hithadhoo
# Processing Record 25 of Set 2 | atuona
# Processing Record 26 of Set 2 | albany
# Processing Record 27 of Set 2 | parfino
# Processing Record 28 of Set 2 | pevek
# Processing Record 29 of Set 2 | luderitz
# Processing Record 30 of Set 2 | naze
# Processing Record 31 of Set 2 | lantawan
# Processing Record 32 of Set 2 | jamestown
# Processing Record 33 of Set 2 | mount isa
# Processing Record 34 of Set 2 | puerto del rosario
# Processing Record 35 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 2 | arethousa
# Processing Record 37 of Set 2 | sao felix do xingu
# Processing Record 38 of Set 2 | avila
# Processing Record 39 of Set 2 | north bend
# Processing Record 40 of Set 2 | tabuk
# Processing Record 41 of Set 2 | souillac
# Processing Record 42 of Set 2 | marienburg
# Processing Record 43 of Set 2 | lavrentiya
# Processing Record 44 of Set 2 | cardenas
# Processing Record 45 of Set 2 | armidale
# Processing Record 46 of Set 2 | krutikha
# Processing Record 47 of Set 2 | nikolskoye
# Processing Record 48 of Set 2 | chenzhou
# Processing Record 49 of Set 2 | taltal
# Processing Record 50 of Set 2 | talnakh
# Processing Record 1 of Set 3 | busselton
# Processing Record 2 of Set 3 | cockburn town
# Processing Record 3 of Set 3 | rabagani
# Processing Record 4 of Set 3 | maniitsoq
# Processing Record 5 of Set 3 | boyolangu
# Processing Record 6 of Set 3 | riyadh
# Processing Record 7 of Set 3 | kavieng
# Processing Record 8 of Set 3 | teofilo otoni
# Processing Record 9 of Set 3 | alofi
# Processing Record 10 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 3 | cervantes
# Processing Record 12 of Set 3 | djibo
# Processing Record 13 of Set 3 | lasa
# Processing Record 14 of Set 3 | upernavik
# Processing Record 15 of Set 3 | armacao de pera
# Processing Record 16 of Set 3 | teya
# Processing Record 17 of Set 3 | gidole
# Processing Record 18 of Set 3 | provideniya
# Processing Record 19 of Set 3 | awjilah
# Processing Record 20 of Set 3 | belaguntha
# Processing Record 21 of Set 3 | saint-pierre
# Processing Record 22 of Set 3 | guerrero negro
# Processing Record 23 of Set 3 | qaanaaq
# Processing Record 24 of Set 3 | tilichiki
# Processing Record 25 of Set 3 | bud
# Processing Record 26 of Set 3 | cabo san lucas
# Processing Record 27 of Set 3 | geraldton
# Processing Record 28 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 3 | butaritari
# Processing Record 30 of Set 3 | kaitangata
# Processing Record 31 of Set 3 | montpellier
# Processing Record 32 of Set 3 | norman wells
# Processing Record 33 of Set 3 | phuket
# Processing Record 34 of Set 3 | nioro
# Processing Record 35 of Set 3 | sao miguel do araguaia
# Processing Record 36 of Set 3 | xingyi
# Processing Record 37 of Set 3 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 38 of Set 3 | bethel
# Processing Record 39 of Set 3 | waipawa
# Processing Record 40 of Set 3 | tiarei
# Processing Record 41 of Set 3 | coquimbo
# Processing Record 42 of Set 3 | tuatapere
# Processing Record 43 of Set 3 | evanston
# Processing Record 44 of Set 3 | nuuk
# Processing Record 45 of Set 3 | hellin
# Processing Record 46 of Set 3 | san cristobal
# Processing Record 47 of Set 3 | pedro ii
# Processing Record 48 of Set 3 | cidreira
# Processing Record 49 of Set 3 | severo-yeniseyskiy
# Processing Record 50 of Set 3 | macamic
# Processing Record 1 of Set 4 | flinders
# Processing Record 2 of Set 4 | strezhevoy
# Processing Record 3 of Set 4 | kalamnuri
# Processing Record 4 of Set 4 | mar del plata
# Processing Record 5 of Set 4 | jiaxing
# Processing Record 6 of Set 4 | tuktoyaktuk
# Processing Record 7 of Set 4 | sylacauga
# Processing Record 8 of Set 4 | bestobe
# Processing Record 9 of Set 4 | upata
# Processing Record 10 of Set 4 | hanyang
# Processing Record 11 of Set 4 | kaoma
# Processing Record 12 of Set 4 | matagami
# Processing Record 13 of Set 4 | sechura
# Processing Record 14 of Set 4 | iskateley
# Processing Record 15 of Set 4 | oriximina
# Processing Record 16 of Set 4 | stamsund
# City not found. Skipping...
# Processing Record 17 of Set 4 | hilo
# Processing Record 18 of Set 4 | ambon
# Processing Record 19 of Set 4 | codrington
# Processing Record 20 of Set 4 | mahebourg
# Processing Record 21 of Set 4 | castro
# Processing Record 22 of Set 4 | yulara
# Processing Record 23 of Set 4 | lompoc
# Processing Record 24 of Set 4 | moa
# Processing Record 25 of Set 4 | turayf
# Processing Record 26 of Set 4 | guangyuan
# Processing Record 27 of Set 4 | monterey
# Processing Record 28 of Set 4 | saskylakh
# Processing Record 29 of Set 4 | isangel
# Processing Record 30 of Set 4 | olafsvik
# Processing Record 31 of Set 4 | arawa
# Processing Record 32 of Set 4 | mehamn
# Processing Record 33 of Set 4 | paciran
# Processing Record 34 of Set 4 | meulaboh
# Processing Record 35 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 4 | salalah
# Processing Record 37 of Set 4 | trat
# Processing Record 38 of Set 4 | evensk
# Processing Record 39 of Set 4 | pathein
# Processing Record 40 of Set 4 | bengkulu
# Processing Record 41 of Set 4 | arman
# Processing Record 42 of Set 4 | san miguel
# Processing Record 43 of Set 4 | palora
# Processing Record 44 of Set 4 | kamina
# Processing Record 45 of Set 4 | fayaoue
# Processing Record 46 of Set 4 | teguise
# Processing Record 47 of Set 4 | saldanha
# Processing Record 48 of Set 4 | anadyr
# Processing Record 49 of Set 4 | buala
# Processing Record 50 of Set 4 | la baule-escoublac
# Processing Record 1 of Set 5 | jinchang
# Processing Record 2 of Set 5 | baykit
# Processing Record 3 of Set 5 | abong mbang
# Processing Record 4 of Set 5 | odessa
# Processing Record 5 of Set 5 | soure
# Processing Record 6 of Set 5 | khasan
# Processing Record 7 of Set 5 | kloulklubed
# Processing Record 8 of Set 5 | buluang
# Processing Record 9 of Set 5 | atar
# Processing Record 10 of Set 5 | chokurdakh
# Processing Record 11 of Set 5 | chake chake
# Processing Record 12 of Set 5 | sabha
# Processing Record 13 of Set 5 | yirol
# City not found. Skipping...
# Processing Record 14 of Set 5 | hongan
# City not found. Skipping...
# Processing Record 15 of Set 5 | wakkanai
# Processing Record 16 of Set 5 | beringovskiy
# Processing Record 17 of Set 5 | taitung
# Processing Record 18 of Set 5 | taoudenni
# Processing Record 19 of Set 5 | victoria
# Processing Record 20 of Set 5 | san pedro
# Processing Record 21 of Set 5 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 22 of Set 5 | kudahuvadhoo
# Processing Record 23 of Set 5 | mabaruma
# Processing Record 24 of Set 5 | port elizabeth
# Processing Record 25 of Set 5 | lucapa
# Processing Record 26 of Set 5 | fort nelson
# Processing Record 27 of Set 5 | whyalla
# Processing Record 28 of Set 5 | goroka
# Processing Record 29 of Set 5 | kesennuma
# City not found. Skipping...
# Processing Record 30 of Set 5 | bafoulabe
# Processing Record 31 of Set 5 | sompeta
# Processing Record 32 of Set 5 | bubaque
# Processing Record 33 of Set 5 | bambous virieux
# Processing Record 34 of Set 5 | esperance
# Processing Record 35 of Set 5 | homer
# Processing Record 36 of Set 5 | shakawe
# Processing Record 37 of Set 5 | touros
# Processing Record 38 of Set 5 | arraial do cabo
# Processing Record 39 of Set 5 | port-gentil
# Processing Record 40 of Set 5 | klyuchi
# Processing Record 41 of Set 5 | bitung
# Processing Record 42 of Set 5 | chon daen
# Processing Record 43 of Set 5 | salinopolis
# Processing Record 44 of Set 5 | airai
# Processing Record 45 of Set 5 | hami
# Processing Record 46 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 5 | eydhafushi
# Processing Record 48 of Set 5 | walvis bay
# Processing Record 49 of Set 5 | khatanga
# Processing Record 50 of Set 5 | gamba
# Processing Record 1 of Set 6 | cherskiy
# Processing Record 2 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 6 | samarai
# Processing Record 4 of Set 6 | klaksvik
# Processing Record 5 of Set 6 | sobolevo
# Processing Record 6 of Set 6 | namibe
# Processing Record 7 of Set 6 | kawalu
# Processing Record 8 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 6 | fairbanks
# Processing Record 10 of Set 6 | cockburn harbour
# City not found. Skipping...
# Processing Record 11 of Set 6 | humberto de campos
# Processing Record 12 of Set 6 | hohhot
# Processing Record 13 of Set 6 | oranjemund
# Processing Record 14 of Set 6 | lorengau
# Processing Record 15 of Set 6 | el alto
# Processing Record 16 of Set 6 | saint anthony
# Processing Record 17 of Set 6 | yarada
# Processing Record 18 of Set 6 | sao filipe
# Processing Record 19 of Set 6 | lashio
# Processing Record 20 of Set 6 | arlit
# Processing Record 21 of Set 6 | berlevag
# Processing Record 22 of Set 6 | narsaq
# Processing Record 23 of Set 6 | warrnambool
# Processing Record 24 of Set 6 | chomun
# City not found. Skipping...
# Processing Record 25 of Set 6 | dikson
# Processing Record 26 of Set 6 | humen
# Processing Record 27 of Set 6 | mecca
# Processing Record 28 of Set 6 | nishihara
# Processing Record 29 of Set 6 | mantua
# Processing Record 30 of Set 6 | ayan
# Processing Record 31 of Set 6 | constitucion
# Processing Record 32 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 33 of Set 6 | shache
# Processing Record 34 of Set 6 | gat
# Processing Record 35 of Set 6 | vengerovo
# Processing Record 36 of Set 6 | pailon
# Processing Record 37 of Set 6 | kahului
# Processing Record 38 of Set 6 | svetlaya
# Processing Record 39 of Set 6 | stromness
# Processing Record 40 of Set 6 | jalcocotan
# Processing Record 41 of Set 6 | aklavik
# Processing Record 42 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 6 | simbahan
# Processing Record 44 of Set 6 | tautira
# Processing Record 45 of Set 6 | cajazeiras
# Processing Record 46 of Set 6 | katangli
# Processing Record 47 of Set 6 | olinda
# Processing Record 48 of Set 6 | eenhana
# Processing Record 49 of Set 6 | chilac
# City not found. Skipping...
# Processing Record 50 of Set 6 | iracoubo
# Processing Record 1 of Set 7 | ponta do sol
# Processing Record 2 of Set 7 | umm kaddadah
# Processing Record 3 of Set 7 | carnarvon
# Processing Record 4 of Set 7 | bilma
# Processing Record 5 of Set 7 | manoel urbano
# Processing Record 6 of Set 7 | port blair
# Processing Record 7 of Set 7 | springbok
# Processing Record 8 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 7 | kentau
# Processing Record 10 of Set 7 | cabanas
# Processing Record 11 of Set 7 | dunedin
# Processing Record 12 of Set 7 | ilo
# Processing Record 13 of Set 7 | port macquarie
# Processing Record 14 of Set 7 | college
# Processing Record 15 of Set 7 | huangchuan
# Processing Record 16 of Set 7 | vao
# Processing Record 17 of Set 7 | muisne
# Processing Record 18 of Set 7 | bonaventure
# Processing Record 19 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 7 | bethal
# Processing Record 21 of Set 7 | katsuura
# Processing Record 22 of Set 7 | nome
# Processing Record 23 of Set 7 | kamien pomorski
# Processing Record 24 of Set 7 | egvekinot
# Processing Record 25 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 7 | nizwa
# Processing Record 27 of Set 7 | ngemplak
# Processing Record 28 of Set 7 | san-pedro
# Processing Record 29 of Set 7 | ust-tsilma
# Processing Record 30 of Set 7 | east london
# Processing Record 31 of Set 7 | hasaki
# Processing Record 32 of Set 7 | beian
# Processing Record 33 of Set 7 | doha
# Processing Record 34 of Set 7 | colac
# Processing Record 35 of Set 7 | husavik
# Processing Record 36 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 37 of Set 7 | obo
# Processing Record 38 of Set 7 | dukat
# Processing Record 39 of Set 7 | sisimiut
# Processing Record 40 of Set 7 | seymchan
# Processing Record 41 of Set 7 | hendijan
# City not found. Skipping...
# Processing Record 42 of Set 7 | mahina
# Processing Record 43 of Set 7 | vanimo
# Processing Record 44 of Set 7 | marsh harbour
# Processing Record 45 of Set 7 | bukama
# Processing Record 46 of Set 7 | huarmey
# Processing Record 47 of Set 7 | muros
# Processing Record 48 of Set 7 | avera
# Processing Record 49 of Set 7 | belaya gora
# Processing Record 50 of Set 7 | cayenne
# Processing Record 1 of Set 8 | vostok
# Processing Record 2 of Set 8 | luneburg
# Processing Record 3 of Set 8 | plettenberg bay
# Processing Record 4 of Set 8 | pavullo nel frignano
# Processing Record 5 of Set 8 | auki
# Processing Record 6 of Set 8 | novosineglazovskiy
# Processing Record 7 of Set 8 | mindelheim
# Processing Record 8 of Set 8 | lima
# Processing Record 9 of Set 8 | torbay
# Processing Record 10 of Set 8 | ancud
# Processing Record 11 of Set 8 | san jose
# Processing Record 12 of Set 8 | shchuchye
# City not found. Skipping...
# Processing Record 13 of Set 8 | te anau
# Processing Record 14 of Set 8 | ostrovnoy
# Processing Record 15 of Set 8 | ketou
# Processing Record 16 of Set 8 | honningsvag
# Processing Record 17 of Set 8 | am timan
# Processing Record 18 of Set 8 | mombetsu
# Processing Record 19 of Set 8 | banda aceh
# Processing Record 20 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 21 of Set 8 | mata
# Processing Record 22 of Set 8 | moroni
# Processing Record 23 of Set 8 | borogontsy
# Processing Record 24 of Set 8 | alta floresta
# Processing Record 25 of Set 8 | fougamou
# Processing Record 26 of Set 8 | waddan
# Processing Record 27 of Set 8 | fort-shevchenko
# Processing Record 28 of Set 8 | terney
# Processing Record 29 of Set 8 | seoul
# Processing Record 30 of Set 8 | shingu
# Processing Record 31 of Set 8 | clyde river
# Processing Record 32 of Set 8 | acapulco
# Processing Record 33 of Set 8 | moyale
# Processing Record 34 of Set 8 | sao raimundo nonato
# Processing Record 35 of Set 8 | bayji
# Processing Record 36 of Set 8 | quatre cocos
# Processing Record 37 of Set 8 | zhezkazgan
# Processing Record 38 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 8 | grand bank
# Processing Record 40 of Set 8 | carutapera
# Processing Record 41 of Set 8 | chardara
# Processing Record 42 of Set 8 | deputatskiy
# Processing Record 43 of Set 8 | road town
# Processing Record 44 of Set 8 | maroantsetra
# Processing Record 45 of Set 8 | rusape
# Processing Record 46 of Set 8 | banmo
# City not found. Skipping...
# Processing Record 47 of Set 8 | puerto escondido
# Processing Record 48 of Set 8 | anton lizardo
# Processing Record 49 of Set 8 | erie
# Processing Record 50 of Set 8 | dindori
# Processing Record 1 of Set 9 | amberley
# Processing Record 2 of Set 9 | ahipara
# Processing Record 3 of Set 9 | yingzhong
# City not found. Skipping...
# Processing Record 4 of Set 9 | okitipupa
# Processing Record 5 of Set 9 | amnat charoen
# Processing Record 6 of Set 9 | hassleholm
# Processing Record 7 of Set 9 | san angelo
# Processing Record 8 of Set 9 | luau
# Processing Record 9 of Set 9 | cabo rojo
# Processing Record 10 of Set 9 | bandundu
# Processing Record 11 of Set 9 | yoichi
# Processing Record 12 of Set 9 | batesville
# Processing Record 13 of Set 9 | general roca
# Processing Record 14 of Set 9 | richards bay
# Processing Record 15 of Set 9 | borama
# City not found. Skipping...
# Processing Record 16 of Set 9 | makakilo city
# Processing Record 17 of Set 9 | hofn
# Processing Record 18 of Set 9 | snasa
# Processing Record 19 of Set 9 | glogow
# Processing Record 20 of Set 9 | haines junction
# Processing Record 21 of Set 9 | lazarev
# Processing Record 22 of Set 9 | zhengjiatun
# Processing Record 23 of Set 9 | talara
# Processing Record 24 of Set 9 | nouadhibou
# Processing Record 25 of Set 9 | hamilton
# Processing Record 26 of Set 9 | alice springs
# Processing Record 27 of Set 9 | vila velha
# Processing Record 28 of Set 9 | gibraleon
# Processing Record 29 of Set 9 | zelenoborsk
# Processing Record 30 of Set 9 | rio grande
# Processing Record 31 of Set 9 | tonstad
# Processing Record 32 of Set 9 | molo
# Processing Record 33 of Set 9 | markala
# Processing Record 34 of Set 9 | ketchikan
# Processing Record 35 of Set 9 | loviisa
# Processing Record 36 of Set 9 | nizhniy odes
# Processing Record 37 of Set 9 | orebro
# Processing Record 38 of Set 9 | bathsheba
# Processing Record 39 of Set 9 | astana
# Processing Record 40 of Set 9 | hambantota
# Processing Record 41 of Set 9 | tunghsiao
# City not found. Skipping...
# Processing Record 42 of Set 9 | alyangula
# Processing Record 43 of Set 9 | kismayo
# Processing Record 44 of Set 9 | maryville
# Processing Record 45 of Set 9 | tieli
# Processing Record 46 of Set 9 | mengcheng
# Processing Record 47 of Set 9 | lavumisa
# Processing Record 48 of Set 9 | tual
# Processing Record 49 of Set 9 | moshi
# Processing Record 50 of Set 9 | ginda
# Processing Record 1 of Set 10 | dovolnoye
# Processing Record 2 of Set 10 | collie
# Processing Record 3 of Set 10 | kingaroy
# Processing Record 4 of Set 10 | unai
# Processing Record 5 of Set 10 | gijon
# Processing Record 6 of Set 10 | komsomolskiy
# Processing Record 7 of Set 10 | harstad
# Processing Record 8 of Set 10 | ruwi
# Processing Record 9 of Set 10 | yeghegnavan
# Processing Record 10 of Set 10 | zaysan
# Processing Record 11 of Set 10 | novaya igirma
# Processing Record 12 of Set 10 | pimentel
# Processing Record 13 of Set 10 | coihaique
# Processing Record 14 of Set 10 | goderich
# Processing Record 15 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 16 of Set 10 | markivka
# Processing Record 17 of Set 10 | vulcanesti
# Processing Record 18 of Set 10 | port hardy
# Processing Record 19 of Set 10 | zhob
# Processing Record 20 of Set 10 | adrar
# Processing Record 21 of Set 10 | fortuna
# Processing Record 22 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 10 | lamar
# Processing Record 24 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 10 | grand gaube
# Processing Record 26 of Set 10 | waspan
# Processing Record 27 of Set 10 | ribeira brava
# Processing Record 28 of Set 10 | oxbow
# Processing Record 29 of Set 10 | russell
# Processing Record 30 of Set 10 | santa ana
# Processing Record 31 of Set 10 | omboue
# Processing Record 32 of Set 10 | armacao dos buzios
# City not found. Skipping...
# Processing Record 33 of Set 10 | saucillo
# Processing Record 34 of Set 10 | wanlaweyn
# Processing Record 35 of Set 10 | asau
# Processing Record 36 of Set 10 | mount gambier
# Processing Record 37 of Set 10 | shenjiamen
# Processing Record 38 of Set 10 | hualmay
# Processing Record 39 of Set 10 | adelaide
# Processing Record 40 of Set 10 | tuy hoa
# Processing Record 41 of Set 10 | batemans bay
# Processing Record 42 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 43 of Set 10 | nabire
# Processing Record 44 of Set 10 | saint-augustin
# Processing Record 45 of Set 10 | san policarpo
# Processing Record 46 of Set 10 | zaterechnyy
# Processing Record 47 of Set 10 | kruisfontein
# Processing Record 48 of Set 10 | dinguiraye
# Processing Record 49 of Set 10 | mandera
# Processing Record 50 of Set 10 | aasiaat
# Processing Record 1 of Set 11 | baker
# Processing Record 2 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 11 | sikeston
# Processing Record 4 of Set 11 | lotofaga
# Processing Record 5 of Set 11 | jardim do serido
# Processing Record 6 of Set 11 | sile
# Processing Record 7 of Set 11 | totness
# Processing Record 8 of Set 11 | banepa
# Processing Record 9 of Set 11 | bilibino
# Processing Record 10 of Set 11 | aleppo
# Processing Record 11 of Set 11 | ust-omchug
# Processing Record 12 of Set 11 | waingapu
# Processing Record 13 of Set 11 | jumla
# Processing Record 14 of Set 11 | magnolia
# Processing Record 15 of Set 11 | mayo
# Processing Record 16 of Set 11 | coahuayana
# Processing Record 17 of Set 11 | sur
# Processing Record 18 of Set 11 | silkeborg
# Processing Record 19 of Set 11 | tevaitoa
# Processing Record 20 of Set 11 | estrela
# Processing Record 21 of Set 11 | daxian
# City not found. Skipping...
# Processing Record 22 of Set 11 | erenhot
# Processing Record 23 of Set 11 | lata
# Processing Record 24 of Set 11 | xadani
# City not found. Skipping...
# Processing Record 25 of Set 11 | nargana
# Processing Record 26 of Set 11 | khormuj
# City not found. Skipping...
# Processing Record 27 of Set 11 | beloha
# Processing Record 28 of Set 11 | mehran
# Processing Record 29 of Set 11 | mogzon
# Processing Record 30 of Set 11 | kenai
# Processing Record 31 of Set 11 | paracuru
# Processing Record 32 of Set 11 | ust-maya
# Processing Record 33 of Set 11 | wynyard
# Processing Record 34 of Set 11 | lufilufi
# Processing Record 35 of Set 11 | coria
# Processing Record 36 of Set 11 | kantunilkin
# Processing Record 37 of Set 11 | huron
# Processing Record 38 of Set 11 | sorland
# Processing Record 39 of Set 11 | burns lake
# Processing Record 40 of Set 11 | van buren
# Processing Record 41 of Set 11 | paranaiba
# Processing Record 42 of Set 11 | gravdal
# Processing Record 43 of Set 11 | bilokurakyne
# Processing Record 44 of Set 11 | iqaluit
# Processing Record 45 of Set 11 | amboasary
# Processing Record 46 of Set 11 | namatanai
# Processing Record 47 of Set 11 | paramonga
# Processing Record 48 of Set 11 | vendome
# Processing Record 49 of Set 11 | la ronge
# Processing Record 50 of Set 11 | irbit
# Processing Record 1 of Set 12 | sovetskiy
# Processing Record 2 of Set 12 | praia da vitoria
# Processing Record 3 of Set 12 | palanga
# Processing Record 4 of Set 12 | baturaja
# Processing Record 5 of Set 12 | prince rupert
# Processing Record 6 of Set 12 | angoche
# Processing Record 7 of Set 12 | mujiayingzi
# Processing Record 8 of Set 12 | tapes
# Processing Record 9 of Set 12 | rio gallegos
# Processing Record 10 of Set 12 | magburaka
# Processing Record 11 of Set 12 | broager
# Processing Record 12 of Set 12 | ixtapa
# Processing Record 13 of Set 12 | iroquois falls
# Processing Record 14 of Set 12 | wanning
# Processing Record 15 of Set 12 | saint george
# Processing Record 16 of Set 12 | catuday
# Processing Record 17 of Set 12 | kolosovka
# Processing Record 18 of Set 12 | ashland
# Processing Record 19 of Set 12 | usinsk
# Processing Record 20 of Set 12 | cheremshan
# Processing Record 21 of Set 12 | odweyne
# Processing Record 22 of Set 12 | natal
# Processing Record 23 of Set 12 | tahlequah
# Processing Record 24 of Set 12 | cape coast
# Processing Record 25 of Set 12 | porto novo
# Processing Record 26 of Set 12 | ajaccio
# Processing Record 27 of Set 12 | parana
# Processing Record 28 of Set 12 | los llanos de aridane
# Processing Record 29 of Set 12 | saurimo
# Processing Record 30 of Set 12 | westport
# Processing Record 31 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 32 of Set 12 | norcasia
# Processing Record 33 of Set 12 | caravelas
# Processing Record 34 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 35 of Set 12 | plouzane
# Processing Record 36 of Set 12 | muzhi
# Processing Record 37 of Set 12 | pangnirtung
# Processing Record 38 of Set 12 | grindavik
# Processing Record 39 of Set 12 | awbari
# Processing Record 40 of Set 12 | half moon bay
# Processing Record 41 of Set 12 | san quintin
# Processing Record 42 of Set 12 | burkhala
# City not found. Skipping...
# Processing Record 43 of Set 12 | broome
# Processing Record 44 of Set 12 | sumbe
# Processing Record 45 of Set 12 | sarkand
# Processing Record 46 of Set 12 | pitimbu
# Processing Record 47 of Set 12 | paramirim
# Processing Record 48 of Set 12 | chapais
# Processing Record 49 of Set 12 | novikovo
# Processing Record 50 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 1 of Set 13 | hare bay
# Processing Record 2 of Set 13 | saint-joseph
# Processing Record 3 of Set 13 | sakaiminato
# Processing Record 4 of Set 13 | yarmouth
# Processing Record 5 of Set 13 | elko
# Processing Record 6 of Set 13 | tungor
# Processing Record 7 of Set 13 | cabedelo
# Processing Record 8 of Set 13 | kristiansund
# Processing Record 9 of Set 13 | zyryanka
# Processing Record 10 of Set 13 | lazaro cardenas
# Processing Record 11 of Set 13 | vila franca do campo
# Processing Record 12 of Set 13 | mayya
# Processing Record 13 of Set 13 | yar-sale
# Processing Record 14 of Set 13 | san carlos de bariloche
# Processing Record 15 of Set 13 | sanislau
# Processing Record 16 of Set 13 | simoes
# Processing Record 17 of Set 13 | nemuro
# Processing Record 18 of Set 13 | baker city
# Processing Record 19 of Set 13 | bakel
# Processing Record 20 of Set 13 | humboldt
# Processing Record 21 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 22 of Set 13 | guatire
# Processing Record 23 of Set 13 | kankan
# Processing Record 24 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 25 of Set 13 | floro
# Processing Record 26 of Set 13 | faya
# Processing Record 27 of Set 13 | tateyama
# Processing Record 28 of Set 13 | hovd
# Processing Record 29 of Set 13 | san javier
# Processing Record 30 of Set 13 | krotoszyn
# Processing Record 31 of Set 13 | na wa
# Processing Record 32 of Set 13 | cholet
# Processing Record 33 of Set 13 | inhambane
# Processing Record 34 of Set 13 | jadu
# Processing Record 35 of Set 13 | boralday
# Processing Record 36 of Set 13 | kosh-agach
# Processing Record 37 of Set 13 | mount hagen
# Processing Record 38 of Set 13 | sao goncalo do amarante
# Processing Record 39 of Set 13 | camenca
# Processing Record 40 of Set 13 | buin
# Processing Record 41 of Set 13 | ambulu
# Processing Record 42 of Set 13 | christchurch
# Processing Record 43 of Set 13 | atasu
# Processing Record 44 of Set 13 | tchamba
# Processing Record 45 of Set 13 | hasanabad
# Processing Record 46 of Set 13 | sterling
# Processing Record 47 of Set 13 | tura
# Processing Record 48 of Set 13 | miandrivazo
# Processing Record 49 of Set 13 | maumere
# Processing Record 50 of Set 13 | lillooet
# Processing Record 1 of Set 14 | lwowek slaski
# Processing Record 2 of Set 14 | bolgatanga
# Processing Record 3 of Set 14 | berezovyy
# Processing Record 4 of Set 14 | mayumba
# Processing Record 5 of Set 14 | lagos
# Processing Record 6 of Set 14 | santa cruz
# Processing Record 7 of Set 14 | riaba
# City not found. Skipping...
# Processing Record 8 of Set 14 | port hedland
# Processing Record 9 of Set 14 | ola
# Processing Record 10 of Set 14 | beira
# Processing Record 11 of Set 14 | brownsville
# Processing Record 12 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 14 | ulladulla
# Processing Record 14 of Set 14 | terra santa
# Processing Record 15 of Set 14 | iskilip
# Processing Record 16 of Set 14 | del rio
# Processing Record 17 of Set 14 | uruguaiana
# Processing Record 18 of Set 14 | ipameri
# Processing Record 19 of Set 14 | ikovka
# Processing Record 20 of Set 14 | faanui
# Processing Record 21 of Set 14 | ippy
# Processing Record 22 of Set 14 | penaflor
# Processing Record 23 of Set 14 | imeni poliny osipenko
# Processing Record 24 of Set 14 | dakar
# Processing Record 25 of Set 14 | solnechnyy
# Processing Record 26 of Set 14 | podor
# Processing Record 27 of Set 14 | beyneu
# Processing Record 28 of Set 14 | tambura
# Processing Record 29 of Set 14 | qui nhon
# Processing Record 30 of Set 14 | basco
# Processing Record 31 of Set 14 | guican
# Processing Record 32 of Set 14 | wasilla
# Processing Record 33 of Set 14 | bonavista
# Processing Record 34 of Set 14 | itarema
# Processing Record 35 of Set 14 | prainha
# Processing Record 36 of Set 14 | dunmore east
# Processing Record 37 of Set 14 | qandala
# Processing Record 38 of Set 14 | odienne
# Processing Record 39 of Set 14 | tessalit
# Processing Record 40 of Set 14 | puerto madryn
# Processing Record 41 of Set 14 | calabozo
# Processing Record 42 of Set 14 | palaikastron
# Processing Record 43 of Set 14 | port-cartier
# Processing Record 44 of Set 14 | iberia
# Processing Record 45 of Set 14 | angra
# City not found. Skipping...
# Processing Record 46 of Set 14 | sinnamary
# Processing Record 47 of Set 14 | po
# City not found. Skipping...
# Processing Record 48 of Set 14 | trairi
# Processing Record 49 of Set 14 | saraland
# Processing Record 50 of Set 14 | buenos aires
# Processing Record 1 of Set 15 | rawson
# Processing Record 2 of Set 15 | pandan
# Processing Record 3 of Set 15 | oranjestad
# Processing Record 4 of Set 15 | kaeo
# Processing Record 5 of Set 15 | itamaraca
# Processing Record 6 of Set 15 | veraval
# Processing Record 7 of Set 15 | sioux lookout
# Processing Record 8 of Set 15 | shahr-e babak
# Processing Record 9 of Set 15 | punta ocote
# Processing Record 10 of Set 15 | ahuimanu
# Processing Record 11 of Set 15 | svetlyy
# Processing Record 12 of Set 15 | tikamgarh
# Processing Record 13 of Set 15 | tefe
# Processing Record 14 of Set 15 | junin
# Processing Record 15 of Set 15 | benjamin hill
# Processing Record 16 of Set 15 | jaipur hat
# City not found. Skipping...
# Processing Record 17 of Set 15 | kupang
# Processing Record 18 of Set 15 | singaraja
# Processing Record 19 of Set 15 | borazjan
# Processing Record 20 of Set 15 | aripuana
# Processing Record 21 of Set 15 | benguela
# Processing Record 22 of Set 15 | kasangulu
# Processing Record 23 of Set 15 | yerbogachen
# Processing Record 24 of Set 15 | skelleftea
# Processing Record 25 of Set 15 | sumenep
# Processing Record 26 of Set 15 | morondava
# Processing Record 27 of Set 15 | benghazi
# Processing Record 28 of Set 15 | barcelos
# Processing Record 29 of Set 15 | san fernando
# Processing Record 30 of Set 15 | aksu
# Processing Record 31 of Set 15 | madang
# Processing Record 32 of Set 15 | moratuwa
# Processing Record 33 of Set 15 | bafra
# Processing Record 34 of Set 15 | sinjai
# Processing Record 35 of Set 15 | erzin
# Processing Record 36 of Set 15 | stoke-on-trent
# Processing Record 37 of Set 15 | camopi
# Processing Record 38 of Set 15 | cacequi
# Processing Record 39 of Set 15 | havre-saint-pierre
# Processing Record 40 of Set 15 | bandarbeyla
# Processing Record 41 of Set 15 | hobyo
# Processing Record 42 of Set 15 | gomel
# Processing Record 43 of Set 15 | matadi
# Processing Record 44 of Set 15 | dali
# Processing Record 45 of Set 15 | conakry
# Processing Record 46 of Set 15 | mercedes
# Processing Record 47 of Set 15 | aykhal
# Processing Record 48 of Set 15 | vilyuysk
# Processing Record 49 of Set 15 | copperas cove
# Processing Record 50 of Set 15 | soyo
# Processing Record 1 of Set 16 | high level
# Processing Record 2 of Set 16 | tagusao
# Processing Record 3 of Set 16 | borodino
# Processing Record 4 of Set 16 | horsham
# Processing Record 5 of Set 16 | barreirinha
# Processing Record 6 of Set 16 | camacha
# Processing Record 7 of Set 16 | manta
# Processing Record 8 of Set 16 | yenagoa
# Processing Record 9 of Set 16 | xining
# Processing Record 10 of Set 16 | umea
# Processing Record 11 of Set 16 | rudnogorsk
# Processing Record 12 of Set 16 | kozhva
# Processing Record 13 of Set 16 | reconquista
# Processing Record 14 of Set 16 | ishinomaki
# Processing Record 15 of Set 16 | mareeba
# Processing Record 16 of Set 16 | nsoko
# Processing Record 17 of Set 16 | ukiah
# Processing Record 18 of Set 16 | luyang
# Processing Record 19 of Set 16 | katobu
# Processing Record 20 of Set 16 | olga
# Processing Record 21 of Set 16 | sabla
# Processing Record 22 of Set 16 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 16 | stupari
# Processing Record 24 of Set 16 | champerico
# Processing Record 25 of Set 16 | susehri
# Processing Record 26 of Set 16 | portland
# Processing Record 27 of Set 16 | dinsor
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 715

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Siavonga -16.5382   28.7088     79.45        74          92
# 1           Hermanus -34.4187   19.2345     75.43        73          44
# 2           Karratha -20.7377  116.8463     82.54        67          14
# 3          Iranshahr  27.2025   60.6848     52.14        93         100
# 4            Mataura -46.1927  168.8643     52.21        98          57
# 5               Chuy -33.6971  -53.4616     80.33        51          11
# 6              Vaini -21.2000 -175.2000     71.76       100          20
# 7        Port Alfred -33.5906   26.8910     81.18        84           9
# 8  Sao Joao Da Barra -21.6403  -41.0511     86.09        81          12
# 9              Pisco -13.7000  -76.2167     71.65        83          40
#
#    Wind Speed Country Current Description
# 0        5.17      ZM          light rain
# 1       14.81      ZA    scattered clouds
# 2        9.04      AU          few clouds
# 3        0.00      IR          light rain
# 4        0.56      NZ       broken clouds
# 5       14.92      UY          few clouds
# 6        0.00      TO          few clouds
# 7       17.76      ZA           clear sky
# 8       10.98      BR          few clouds
# 9        6.91      PE                mist

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Siavonga      ZM -16.5382   28.7088     79.45        74
# 1           Hermanus      ZA -34.4187   19.2345     75.43        73
# 2           Karratha      AU -20.7377  116.8463     82.54        67
# 3          Iranshahr      IR  27.2025   60.6848     52.14        93
# 4            Mataura      NZ -46.1927  168.8643     52.21        98
# 5               Chuy      UY -33.6971  -53.4616     80.33        51
# 6              Vaini      TO -21.2000 -175.2000     71.76       100
# 7        Port Alfred      ZA -33.5906   26.8910     81.18        84
# 8  Sao Joao Da Barra      BR -21.6403  -41.0511     86.09        81
# 9              Pisco      PE -13.7000  -76.2167     71.65        83
#
#    Cloudiness  Wind Speed Current Description
# 0          92        5.17          light rain
# 1          44       14.81    scattered clouds
# 2          14        9.04          few clouds
# 3         100        0.00          light rain
# 4          57        0.56       broken clouds
# 5          11       14.92          few clouds
# 6          20        0.00          few clouds
# 7           9       17.76           clear sky
# 8          12       10.98          few clouds
# 9          40        6.91                mist

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label = "City_ID")
